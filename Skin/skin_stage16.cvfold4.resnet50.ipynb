# %% [markdown]
# <a href="https://www.kaggle.com/code/ab0y04/skin-lesion-imagenet?scriptVersionId=344413934" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# ===== FULL REBUILD (new session) + STAGE 16 FOLD 4: RESNET50 =====
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'   # MUST precede tensorflow import
import random, gc
import numpy as np
import pandas as pd
import tensorflow as tf

SEED = 42  # fixed globally across ALL folds and ALL architectures
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
print(f"Seed {SEED} set, TF {tf.__version__}, tf.keras module: {tf.keras.__name__}")
assert 'tf_keras' in tf.keras.__name__, "STOP: Keras 3 active, not legacy. Restart before continuing."

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as res_pre
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, recall_score, confusion_matrix
print("Imports ready")

FINAL_CLASSES = ['bcc', 'bkl', 'df', 'melanoma', 'nevus', 'vasc']
NUM_CLASSES = 6
IMG_SIZE, BATCH_SIZE = 224, 32
N_FOLDS, CURRENT_FOLD = 5, 4
AUG = dict(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
           horizontal_flip=True, zoom_range=0.1)
print(f"Config loaded, CURRENT_FOLD = {CURRENT_FOLD}")

CV_ASSIGN_PATH = '/kaggle/input/datasets/ab0y04/cvfoldassignments/cv_fold_assignments.csv'
assert os.path.exists(CV_ASSIGN_PATH), f"STOP: file not found at {CV_ASSIGN_PATH}, check the dataset is attached"
cv_assignments = pd.read_csv(CV_ASSIGN_PATH)
print(f"Loaded cv_fold_assignments.csv: {len(cv_assignments):,} rows (expect 23,836)")
assert len(cv_assignments) == 23836, "STOP: row count mismatch"

def build_fold_split(cv_assignments, fold_num, seed=42):
    test_df = cv_assignments[cv_assignments['fold'] == fold_num].reset_index(drop=True)
    remaining = cv_assignments[cv_assignments['fold'] != fold_num].reset_index(drop=True)
    remaining = remaining.copy()
    fallback = pd.Series('unlinked_' + remaining.index.astype(str), index=remaining.index)
    remaining['_split_key'] = remaining['group_id'].fillna(fallback)
    groups = remaining.groupby('_split_key')['label'].first().reset_index()
    tr_groups, va_groups = train_test_split(groups, test_size=0.15, stratify=groups['label'], random_state=seed)
    train_df = remaining[remaining['_split_key'].isin(tr_groups['_split_key'])].drop(columns=['_split_key']).reset_index(drop=True)
    val_df = remaining[remaining['_split_key'].isin(va_groups['_split_key'])].drop(columns=['_split_key']).reset_index(drop=True)
    return train_df, val_df, test_df

train_df, val_df, test_df = build_fold_split(cv_assignments, CURRENT_FOLD, seed=SEED)
print(f"\n===== FOLD {CURRENT_FOLD} SPLIT =====")
print(f"Train {len(train_df):,} | Val {len(val_df):,} | Test {len(test_df):,}")
print("(expect to match this fold's prior runs exactly: 16,262 / 2,891 / 4,683)")

test_groups = set(test_df['group_id'].dropna())
train_groups = set(train_df['group_id'].dropna())
val_groups = set(val_df['group_id'].dropna())
assert test_groups.isdisjoint(train_groups) and test_groups.isdisjoint(val_groups) and train_groups.isdisjoint(val_groups), \
    f"STOP: FOLD {CURRENT_FOLD} LEAKAGE detected"
print(f"Fold {CURRENT_FOLD} leakage check: PASS")

cls = np.array(FINAL_CLASSES)
cw = compute_class_weight('balanced', classes=cls, y=train_df['label'])
w_map = {c: w for c, w in zip(FINAL_CLASSES, cw)}
train_df['sample_weight'] = train_df['label'].map(w_map)
print(f"Fold {CURRENT_FOLD} class_weight:", {c: round(w,3) for c,w in zip(cls, cw)})
print("(expect: bcc 1.209, df 15.943, nevus 0.308)")

def make_fold_gens(preprocess_fn):
    train_idg = ImageDataGenerator(preprocessing_function=preprocess_fn, **AUG)
    eval_idg  = ImageDataGenerator(preprocessing_function=preprocess_fn)
    common = dict(x_col='image_path', y_col='label', target_size=(IMG_SIZE,IMG_SIZE),
                  batch_size=BATCH_SIZE, class_mode='categorical', classes=FINAL_CLASSES)
    tr = train_idg.flow_from_dataframe(train_df, shuffle=True, seed=SEED, weight_col='sample_weight', **common)
    va = eval_idg.flow_from_dataframe(val_df, shuffle=False, **common)
    te = eval_idg.flow_from_dataframe(test_df, shuffle=False, **common)
    return tr, va, te

def build_pretrained(base_class, num_classes=6, shape=(224,224,3)):
    base = base_class(include_top=False, weights='imagenet', input_shape=shape)
    model = Sequential([base, GlobalAveragePooling2D(), Dense(256,activation='relu'),
                          Dropout(0.3), Dense(num_classes,activation='softmax')])
    return model, base

def macro_specificity(y_true, y_pred, n_classes):
    cm = confusion_matrix(y_true, y_pred, labels=range(n_classes))
    total = cm.sum(); specs = []
    for i in range(n_classes):
        tp = cm[i,i]; fn = cm[i,:].sum()-tp; fp = cm[:,i].sum()-tp
        tn = total-tp-fn-fp
        specs.append(tn/(tn+fp) if (tn+fp)>0 else np.nan)
    return np.nanmean(specs)

print(f"\n===== Fold {CURRENT_FOLD} setup verified. Training ResNet50. =====\n")

# ---------- RESNET50, FOLD 4 ----------
tr, va, te = make_fold_gens(res_pre)
print("class_indices:", te.class_indices)

model, base = build_pretrained(ResNet50)
log_file = f'/kaggle/working/cv_f{CURRENT_FOLD}_res_log.csv'

base.trainable = False
model.compile(Adam(1e-3), 'categorical_crossentropy', ['accuracy'])
model.fit(tr, validation_data=va, epochs=10, callbacks=[CSVLogger(log_file, append=False)], verbose=1)
print("Phase 1 sanity:", model.evaluate(te, verbose=0))

base.trainable = True
model.compile(Adam(1e-5), 'categorical_crossentropy', ['accuracy'])
cbs = [EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True),
       ModelCheckpoint(f'/kaggle/working/cv_f{CURRENT_FOLD}_res.keras', monitor='val_accuracy', save_best_only=True),
       CSVLogger(log_file, append=True)]
model.fit(tr, validation_data=va, epochs=60, callbacks=cbs, verbose=1)

y_true = np.asarray(te.classes)
y_prob = model.predict(te, verbose=0)
y_pred = np.argmax(y_prob, axis=1)
np.savez(f'/kaggle/working/cv_f{CURRENT_FOLD}_preds_res.npz', y_true=y_true, y_pred=y_pred, y_prob=y_prob)

reloaded = load_model(f'/kaggle/working/cv_f{CURRENT_FOLD}_res.keras')
verify_acc = reloaded.evaluate(te, verbose=0)[1]
live_acc = accuracy_score(y_true, y_pred)
print(f"Checkpoint verify: reloaded acc {verify_acc:.4f} vs live acc {live_acc:.4f}  match={abs(verify_acc-live_acc)<1e-3}")
del reloaded; gc.collect(); tf.keras.backend.clear_session()

result_row = dict(fold=CURRENT_FOLD, arch='res', accuracy=live_acc,
    macro_f1=f1_score(y_true,y_pred,average='macro'),
    macro_auc=roc_auc_score(np.eye(NUM_CLASSES)[y_true], y_prob, average='macro', multi_class='ovr'),
    macro_sensitivity=recall_score(y_true,y_pred,average='macro'),
    macro_specificity=macro_specificity(y_true,y_pred,NUM_CLASSES), n_test=len(y_true))

FOLD_ACC_RES = [0.7428098489551004, 0.7191865242399342, 0.7183424484644509]
prior_mean = np.mean(FOLD_ACC_RES)
deviation = abs(live_acc - prior_mean) * 100
flag = "  <-- FLAG: deviates >5pp from folds 1-3 mean" if deviation > 5 else "  (within normal range)"
print(f"\nFold {CURRENT_FOLD} vs Folds 1-3 mean: {live_acc:.4f} vs {prior_mean:.4f}, deviation {deviation:.1f}pp{flag}")

pd.DataFrame([result_row]).to_csv(f'/kaggle/working/cv_f{CURRENT_FOLD}_res_result.csv', index=False)
print(f"\nRESULT: {result_row}")
print(f"Saved: /kaggle/working/cv_f{CURRENT_FOLD}_res_result.csv")
print(">>> DOWNLOAD THIS FILE TO YOUR COMPUTER NOW. <<<")
print(f"\nFold {CURRENT_FOLD} will be complete after this: custom, eff, mob, res all trained.")
# Out:
# 2026-08-23 16:57:19.004870: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1787504239.223493      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1787504239.288360      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1787504239.823658      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787504239.823701      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787504239.823704      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787504239.823707      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seed 42 set, TF 2.19.0, tf.keras module: tf_keras.api._v2.keras
# Imports ready
# Config loaded, CURRENT_FOLD = 4
# Loaded cv_fold_assignments.csv: 23,836 rows (expect 23,836)
#
# ===== FOLD 4 SPLIT =====
# Train 16,262 | Val 2,891 | Test 4,683
# (expect to match this fold's prior runs exactly: 16,262 / 2,891 / 4,683)
# Fold 4 leakage check: PASS
# Fold 4 class_weight: {np.str_('bcc'): np.float64(1.209), np.str_('bkl'): np.float64(1.519), np.str_('df'): np.float64(15.943), np.str_('melanoma'): np.float64(0.872), np.str_('nevus'): np.float64(0.308), np.str_('vasc'): np.float64(15.758)}
# (expect: bcc 1.209, df 15.943, nevus 0.308)
#
# ===== Fold 4 setup verified. Training ResNet50. =====
#
# Found 16262 validated image filenames belonging to 6 classes.
# Found 2891 validated image filenames belonging to 6 classes.
# Found 4683 validated image filenames belonging to 6 classes.
# class_indices: {'bcc': 0, 'bkl': 1, 'df': 2, 'melanoma': 3, 'nevus': 4, 'vasc': 5}
# I0000 00:00:1787504325.738154      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1787504325.744001      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Epoch 1/10
# I0000 00:00:1787504334.233303      67 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787504336.586472      66 service.cc:152] XLA service 0x78bbec389930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1787504336.586522      66 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1787504336.586529      66 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1787504336.859259      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 509/509 [==============================] - 599s 1s/step - loss: 1.4438 - accuracy: 0.4755 - val_loss: 1.1469 - val_accuracy: 0.5524
# Epoch 2/10
# 509/509 [==============================] - 376s 738ms/step - loss: 1.1480 - accuracy: 0.5376 - val_loss: 1.0380 - val_accuracy: 0.5870
# Epoch 3/10
# 509/509 [==============================] - 382s 750ms/step - loss: 1.0642 - accuracy: 0.5521 - val_loss: 0.9866 - val_accuracy: 0.6195
# Epoch 4/10
# 509/509 [==============================] - 383s 753ms/step - loss: 0.9846 - accuracy: 0.5622 - val_loss: 1.0918 - val_accuracy: 0.5358
# Epoch 5/10
# 509/509 [==============================] - 374s 734ms/step - loss: 0.9700 - accuracy: 0.5721 - val_loss: 1.0260 - val_accuracy: 0.6050
# Epoch 6/10
# 509/509 [==============================] - 374s 734ms/step - loss: 0.9210 - accuracy: 0.5799 - val_loss: 1.0097 - val_accuracy: 0.5984
# Epoch 7/10
# 509/509 [==============================] - 377s 741ms/step - loss: 0.8955 - accuracy: 0.5927 - val_loss: 0.9912 - val_accuracy: 0.6098
# Epoch 8/10
# 509/509 [==============================] - 380s 746ms/step - loss: 0.8514 - accuracy: 0.6000 - val_loss: 1.0178 - val_accuracy: 0.5936
# Epoch 9/10
# 509/509 [==============================] - 378s 743ms/step - loss: 0.8401 - accuracy: 0.6072 - val_loss: 0.9254 - val_accuracy: 0.6233
# Epoch 10/10
# 509/509 [==============================] - 377s 741ms/step - loss: 0.8200 - accuracy: 0.6066 - val_loss: 1.0083 - val_accuracy: 0.6043
# Phase 1 sanity: [1.043664813041687, 0.6040999293327332]
# Epoch 1/60
# 509/509 [==============================] - 567s 1s/step - loss: 1.7015 - accuracy: 0.4792 - val_loss: 1.1290 - val_accuracy: 0.5617
# Epoch 2/60
# 509/509 [==============================] - 529s 1s/step - loss: 0.8578 - accuracy: 0.5760 - val_loss: 1.0170 - val_accuracy: 0.5994
# Epoch 3/60
# 509/509 [==============================] - 517s 1s/step - loss: 0.7421 - accuracy: 0.6167 - val_loss: 0.9603 - val_accuracy: 0.6167
# Epoch 4/60
# 509/509 [==============================] - 528s 1s/step - loss: 0.6600 - accuracy: 0.6521 - val_loss: 0.9143 - val_accuracy: 0.6496
# Epoch 5/60
# 509/509 [==============================] - 522s 1s/step - loss: 0.5909 - accuracy: 0.6749 - val_loss: 0.8771 - val_accuracy: 0.6586
# Epoch 6/60
# 509/509 [==============================] - 534s 1s/step - loss: 0.5544 - accuracy: 0.6939 - val_loss: 0.8532 - val_accuracy: 0.6638
# Epoch 7/60
# 509/509 [==============================] - 535s 1s/step - loss: 0.5008 - accuracy: 0.7130 - val_loss: 0.8294 - val_accuracy: 0.6825
# Epoch 8/60
# 509/509 [==============================] - 523s 1s/step - loss: 0.4716 - accuracy: 0.7323 - val_loss: 0.8092 - val_accuracy: 0.6838
# Epoch 9/60
# 509/509 [==============================] - 520s 1s/step - loss: 0.4402 - accuracy: 0.7425 - val_loss: 0.8309 - val_accuracy: 0.6928
# Epoch 10/60
# 509/509 [==============================] - 517s 1s/step - loss: 0.4123 - accuracy: 0.7576 - val_loss: 0.8450 - val_accuracy: 0.6928
# Epoch 11/60
# 509/509 [==============================] - 520s 1s/step - loss: 0.3818 - accuracy: 0.7691 - val_loss: 0.8008 - val_accuracy: 0.7060
# Epoch 12/60
# 509/509 [==============================] - 519s 1s/step - loss: 0.3555 - accuracy: 0.7909 - val_loss: 0.8957 - val_accuracy: 0.6901
# Epoch 13/60
# 509/509 [==============================] - 540s 1s/step - loss: 0.3387 - accuracy: 0.7945 - val_loss: 0.8245 - val_accuracy: 0.7084
# Epoch 14/60
# 509/509 [==============================] - 533s 1s/step - loss: 0.3154 - accuracy: 0.8115 - val_loss: 0.9150 - val_accuracy: 0.6942
# Epoch 15/60
# 509/509 [==============================] - 527s 1s/step - loss: 0.2863 - accuracy: 0.8266 - val_loss: 0.8742 - val_accuracy: 0.7084
# Epoch 16/60
# 509/509 [==============================] - 520s 1s/step - loss: 0.2768 - accuracy: 0.8355 - val_loss: 0.9021 - val_accuracy: 0.6980
# Epoch 17/60
# 509/509 [==============================] - 521s 1s/step - loss: 0.2585 - accuracy: 0.8387 - val_loss: 0.8990 - val_accuracy: 0.7222
# Epoch 18/60
# 509/509 [==============================] - 523s 1s/step - loss: 0.2357 - accuracy: 0.8519 - val_loss: 0.8888 - val_accuracy: 0.7219
# Epoch 19/60
# 509/509 [==============================] - 525s 1s/step - loss: 0.2133 - accuracy: 0.8655 - val_loss: 0.9917 - val_accuracy: 0.7215
# Epoch 20/60
# 509/509 [==============================] - 539s 1s/step - loss: 0.2082 - accuracy: 0.8695 - val_loss: 0.8858 - val_accuracy: 0.7361
# Epoch 21/60
# 509/509 [==============================] - 524s 1s/step - loss: 0.1996 - accuracy: 0.8800 - val_loss: 0.8916 - val_accuracy: 0.7430
# Epoch 22/60
# 509/509 [==============================] - 526s 1s/step - loss: 0.1774 - accuracy: 0.8870 - val_loss: 0.9087 - val_accuracy: 0.7337
# Epoch 23/60
# 509/509 [==============================] - 527s 1s/step - loss: 0.1577 - accuracy: 0.9006 - val_loss: 0.9822 - val_accuracy: 0.7333
# Epoch 24/60
# 509/509 [==============================] - 522s 1s/step - loss: 0.1466 - accuracy: 0.9049 - val_loss: 0.9643 - val_accuracy: 0.7285
# Epoch 25/60
# 509/509 [==============================] - 522s 1s/step - loss: 0.1494 - accuracy: 0.9087 - val_loss: 0.9687 - val_accuracy: 0.7489
# Epoch 26/60
# 509/509 [==============================] - 522s 1s/step - loss: 0.1419 - accuracy: 0.9108 - val_loss: 0.9997 - val_accuracy: 0.7444
# Epoch 27/60
# 509/509 [==============================] - 541s 1s/step - loss: 0.1236 - accuracy: 0.9192 - val_loss: 1.0305 - val_accuracy: 0.7371
# Epoch 28/60
# 509/509 [==============================] - 520s 1s/step - loss: 0.1179 - accuracy: 0.9263 - val_loss: 1.0398 - val_accuracy: 0.7478
# Epoch 29/60
# 509/509 [==============================] - 521s 1s/step - loss: 0.1083 - accuracy: 0.9277 - val_loss: 1.0100 - val_accuracy: 0.7475
# Epoch 30/60
# 509/509 [==============================] - 520s 1s/step - loss: 0.1084 - accuracy: 0.9300 - val_loss: 1.0751 - val_accuracy: 0.7402
# Epoch 31/60
# 509/509 [==============================] - 519s 1s/step - loss: 0.1210 - accuracy: 0.9298 - val_loss: 1.0805 - val_accuracy: 0.7406
# Epoch 32/60
# 509/509 [==============================] - 524s 1s/step - loss: 0.1002 - accuracy: 0.9408 - val_loss: 1.2880 - val_accuracy: 0.7399
# Checkpoint verify: reloaded acc 0.7457 vs live acc 0.7457  match=True
#
# Fold 4 vs Folds 1-3 mean: 0.7457 vs 0.7268, deviation 1.9pp  (within normal range)
#
# RESULT: {'fold': 4, 'arch': 'res', 'accuracy': 0.7456758488148623, 'macro_f1': 0.633358592053891, 'macro_auc': np.float64(0.9256035461936949), 'macro_sensitivity': 0.6613387099279971, 'macro_specificity': np.float64(0.9385531769735497), 'n_test': 4683}
# Saved: /kaggle/working/cv_f4_res_result.csv
# >>> DOWNLOAD THIS FILE TO YOUR COMPUTER NOW. <<<
#
# Fold 4 will be complete after this: custom, eff, mob, res all trained.
