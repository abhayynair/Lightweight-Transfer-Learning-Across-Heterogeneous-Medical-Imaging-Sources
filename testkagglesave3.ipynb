# %%
# This Python 3 environment comes with many helpful analytics libraries installed
## ===== FULL REBUILD (new session) + EXPLICIT CHECKS + STAGE 15 LAMBDA DIAGNOSTIC =====
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'   # MUST precede tensorflow import
import random, gc, time
import numpy as np
import pandas as pd
import tensorflow as tf
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
print(f"Seed {SEED} set, TF {tf.__version__}, tf.keras module: {tf.keras.__name__}, this is test3")
assert 'tf_keras' in tf.keras.__name__, "STOP: Keras 3 active, not legacy. Restart before continuing."

# ===== SAVE FUNCTIONALITY TEST, no dataset needed =====
import datetime

output_path = '/kaggle/working/save_test_output2.txt'

with open(output_path, 'w') as f:
    f.write(f"Save test successful\n")
    f.write(f"Written at: {datetime.datetime.now()}\n")
    f.write(f"TF version confirmed: {tf.__version__}\n")
    f.write(f"Seed confirmed: {SEED}\n")
    f.write(f"This proves the notebook executed top to bottom and wrote to /kaggle/working/\n")

print(f"File written to: {output_path}")
print("Contents:")
with open(output_path, 'r') as f:
    print(f.read())

# also confirm it's visible on disk right now, in this session
print("Files currently in /kaggle/working/:")
print(os.listdir('/kaggle/working/'))
# Out:
# Seed 42 set, TF 2.20.0, tf.keras module: tf_keras.api._v2.keras, this is test3
# File written to: /kaggle/working/save_test_output2.txt
# Contents:
# Save test successful
# Written at: 2026-08-03 21:01:00.174747
# TF version confirmed: 2.20.0
# Seed confirmed: 42
# This proves the notebook executed top to bottom and wrote to /kaggle/working/
#
# Files currently in /kaggle/working/:
# ['save_test_output2.txt', '__notebook__.ipynb']
