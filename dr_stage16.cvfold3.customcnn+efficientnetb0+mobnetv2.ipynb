# %% [markdown]
# <a href="https://www.kaggle.com/code/asivakumarnair/diabetic-retinopathy-imagenet?scriptVersionId=345109889" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# ===== STAGE 16 SESSION: FOLD 3, CUSTOM CNN + EFFICIENTNETB0 + MOBILENETV2 (loads locked fold file, never regenerates) =====
# First touch on fold 3. This session ESTABLISHES fold 3's split sizes and class weight span.
# A later ResNet50-only session for fold 3 will need to assert reproduction against whatever prints here.

# !pip install -q tensorflow==2.19.0

import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

import random
import numpy as np
import pandas as pd
import tensorflow as tf

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
print(f"Seed {SEED} set, TF {tf.__version__}, tf.keras module: {tf.keras.__name__}")
assert 'tf_keras' in tf.keras.__name__, "STOP: Keras 3 active, not legacy. Restart before continuing."

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization, MaxPooling2D,
                                      Dropout, GlobalAveragePooling2D, Dense)
from tensorflow.keras.applications import EfficientNetB0, MobileNetV2
from tensorflow.keras.applications.efficientnet import preprocess_input as eff_pre
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mob_pre
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import (cohen_kappa_score, roc_auc_score, accuracy_score,
                              f1_score, recall_score, confusion_matrix)

# ---------- LOAD LOCKED FOLD ASSIGNMENTS, DO NOT REGENERATE ----------
FOLD_CSV_PATH = '/kaggle/input/datasets/asivakumarnair/drcvfoldassignments/dr_cv_fold_assignments.csv'

GRADES, NUM_CLASSES = ['0','1','2','3','4'], 5
IMG_SIZE, BATCH_SIZE = 224, 32
PHASE1_EPOCHS, PHASE1_LR, PHASE2_LR, CUSTOM_LR, EARLYSTOP_PAT = 10, 1e-3, 1e-5, 1e-3, 7
AUG = dict(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
           horizontal_flip=True, zoom_range=0.1)
CURRENT_FOLD = 3

pooled = pd.read_csv(FOLD_CSV_PATH)
pooled['grade'] = pooled['grade'].astype(str)
print(f"Loaded {len(pooled):,} rows (expect 9,068)")
assert len(pooled) == 9068, "Row count mismatch, wrong file or corrupted upload"
assert pooled['fold'].nunique() == 5, "Fold file does not have 5 folds"

test_df   = pooled[pooled.fold == CURRENT_FOLD].reset_index(drop=True)
remainder = pooled[pooled.fold != CURRENT_FOLD].reset_index(drop=True)

def safe_split(df, label_col, test_size, rs, tag=""):
    try:
        return train_test_split(df, test_size=test_size, stratify=df[label_col], random_state=rs)
    except ValueError as e:
        print(f"WARNING [{tag}]: stratified split failed, unstratified fallback. {e}")
        return train_test_split(df, test_size=test_size, random_state=rs)

def split_group_level_inner(df, label_col='grade', val_frac=0.15, rs=SEED, tag=""):
    grouped = df.groupby('group_id')[label_col].agg(lambda s: s.value_counts().index[0]).reset_index()
    g_tr, g_va = safe_split(grouped, label_col, val_frac, rs, tag=tag)
    pick = lambda ids: df[df['group_id'].isin(ids['group_id'])]
    return pick(g_tr), pick(g_va)

train_parts, val_parts = [], []
for src in ['aptos', 'eyepacs', 'messidor']:
    sub = remainder[remainder.source == src]
    tr_s, va_s = split_group_level_inner(sub, tag=f"fold{CURRENT_FOLD}-{src}-inner")
    train_parts.append(tr_s); val_parts.append(va_s)
train_df = pd.concat(train_parts, ignore_index=True)
val_df   = pd.concat(val_parts, ignore_index=True)

print(f"\nFold {CURRENT_FOLD}: Train {len(train_df):,} ({len(train_df)/len(pooled)*100:.1f}%) | "
      f"Val {len(val_df):,} ({len(val_df)/len(pooled)*100:.1f}%) | "
      f"Test {len(test_df):,} ({len(test_df)/len(pooled)*100:.1f}%)")
print("^^ RECORD THESE NUMBERS. The fold 3 ResNet50 session will assert reproduction against them.")

for src in ['aptos', 'eyepacs', 'messidor']:
    tr_g = set(train_df[train_df.source==src]['group_id'])
    va_g = set(val_df[val_df.source==src]['group_id'])
    te_g = set(test_df[test_df.source==src]['group_id'])
    ok = tr_g.isdisjoint(va_g) and tr_g.isdisjoint(te_g) and va_g.isdisjoint(te_g)
    print(f"  {src}: train/val/test group-disjoint = {ok}")
    assert ok, f"LEAKAGE in fold {CURRENT_FOLD}, source {src}"
print(f"Fold {CURRENT_FOLD} leakage check: PASS")

cls = np.array(GRADES)
cw = compute_class_weight('balanced', classes=cls, y=train_df['grade'])
CLASS_WEIGHT = {i: w for i, w in enumerate(cw)}
print(f"Fold {CURRENT_FOLD} class_weight (fresh from this fold's train set):",
      {c: round(w,3) for c,w in zip(cls,cw)}, f"| span {cw.max()/cw.min():.1f}x")
print("^^ RECORD THIS SPAN too, same reproduction requirement.")

def make_gens(preprocess_fn):
    if preprocess_fn is None:
        train_idg = ImageDataGenerator(rescale=1./255, **AUG)
        eval_idg  = ImageDataGenerator(rescale=1./255)
    else:
        train_idg = ImageDataGenerator(preprocessing_function=preprocess_fn, **AUG)
        eval_idg  = ImageDataGenerator(preprocessing_function=preprocess_fn)
    common = dict(x_col='image_path', y_col='grade', target_size=(IMG_SIZE,IMG_SIZE), batch_size=BATCH_SIZE,
                  class_mode='categorical', classes=GRADES, color_mode='rgb')
    return (train_idg.flow_from_dataframe(train_df, shuffle=True, seed=SEED, **common),
            eval_idg.flow_from_dataframe(val_df, shuffle=False, **common),
            eval_idg.flow_from_dataframe(test_df, shuffle=False, **common))

def build_custom_cnn(num_classes=5, shape=(224,224,3)):
    return Sequential([
        Input(shape=shape),
        Conv2D(32,3,padding='same',activation='relu'), BatchNormalization(),
        Conv2D(32,3,padding='same',activation='relu'), BatchNormalization(),
        MaxPooling2D(), Dropout(0.25),
        Conv2D(64,3,padding='same',activation='relu'), BatchNormalization(),
        Conv2D(64,3,padding='same',activation='relu'), BatchNormalization(),
        MaxPooling2D(), Dropout(0.25),
        Conv2D(128,3,padding='same',activation='relu'), BatchNormalization(),
        Conv2D(128,3,padding='same',activation='relu'), BatchNormalization(),
        MaxPooling2D(), Dropout(0.25),
        GlobalAveragePooling2D(),
        Dense(256,activation='relu'), Dropout(0.5),
        Dense(num_classes,activation='softmax')
    ])

def build_pretrained(base_class, num_classes=5, shape=(224,224,3)):
    base = base_class(include_top=False, weights='imagenet', input_shape=shape)
    model = Sequential([base, GlobalAveragePooling2D(), Dense(256,activation='relu'),
                        Dropout(0.3), Dense(num_classes,activation='softmax')])
    return model, base

def macro_specificity(y_true, y_pred, n_classes=NUM_CLASSES):
    cm = confusion_matrix(y_true, y_pred, labels=range(n_classes))
    total = cm.sum(); specs = []
    for i in range(n_classes):
        tp = cm[i,i]; fn = cm[i,:].sum()-tp; fp = cm[:,i].sum()-tp
        tn = total-tp-fn-fp
        specs.append(tn/(tn+fp) if (tn+fp) > 0 else np.nan)
    return np.nanmean(specs)

def full_test_metrics(model, te_gen):
    y_prob = model.predict(te_gen, verbose=0)
    y_true = np.asarray(te_gen.classes)
    y_pred = y_prob.argmax(axis=1)
    try:
        auc = roc_auc_score(np.eye(NUM_CLASSES)[y_true], y_prob, average='macro', multi_class='ovr')
    except ValueError:
        auc = np.nan
    return dict(qwk=cohen_kappa_score(y_true, y_pred, weights='quadratic'), macro_auc=auc,
                accuracy=accuracy_score(y_true, y_pred),
                macro_f1=f1_score(y_true, y_pred, average='macro'),
                macro_sensitivity=recall_score(y_true, y_pred, average='macro'),
                macro_specificity=macro_specificity(y_true, y_pred), n_test=len(y_true)), y_true, y_pred, y_prob

def train_and_evaluate(arch_code, build_fn, preprocess_fn, is_pretrained):
    tr, va, te = make_gens(preprocess_fn)
    auc_path = f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_aucbest.keras'
    acc_path = f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_accbest.keras'

    if is_pretrained:
        model, base = build_fn()
        base.trainable = False
        model.compile(Adam(PHASE1_LR), 'categorical_crossentropy',
                      metrics=['accuracy', tf.keras.metrics.AUC(name='auc', multi_label=False)])
        print(f"\n===== Fold {CURRENT_FOLD}, {arch_code}: PHASE 1 (head only, {PHASE1_EPOCHS} epochs) =====")
        model.fit(tr, validation_data=va, epochs=PHASE1_EPOCHS, class_weight=CLASS_WEIGHT, verbose=1,
                  callbacks=[CSVLogger(f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_log.csv', append=False)])
        base.trainable = True
        model.compile(Adam(PHASE2_LR), 'categorical_crossentropy',
                      metrics=['accuracy', tf.keras.metrics.AUC(name='auc', multi_label=False)])
        print(f"\n===== Fold {CURRENT_FOLD}, {arch_code}: PHASE 2 (full fine-tune, dual checkpoint) =====")
        hist = model.fit(tr, validation_data=va, epochs=60, class_weight=CLASS_WEIGHT, verbose=1,
                  callbacks=[EarlyStopping(monitor='val_auc', mode='max', patience=EARLYSTOP_PAT, restore_best_weights=True),
                             ModelCheckpoint(auc_path, monitor='val_auc', mode='max', save_best_only=True),
                             ModelCheckpoint(acc_path, monitor='val_accuracy', mode='max', save_best_only=True),
                             CSVLogger(f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_log.csv', append=True)])
    else:
        model = build_fn()
        model.compile(Adam(CUSTOM_LR), 'categorical_crossentropy',
                      metrics=['accuracy', tf.keras.metrics.AUC(name='auc', multi_label=False)])
        print(f"\n===== Fold {CURRENT_FOLD}, {arch_code}: single phase, dual checkpoint =====")
        hist = model.fit(tr, validation_data=va, epochs=60, class_weight=CLASS_WEIGHT, verbose=1,
                  callbacks=[EarlyStopping(monitor='val_auc', mode='max', patience=EARLYSTOP_PAT, restore_best_weights=True),
                             ModelCheckpoint(auc_path, monitor='val_auc', mode='max', save_best_only=True),
                             ModelCheckpoint(acc_path, monitor='val_accuracy', mode='max', save_best_only=True),
                             CSVLogger(f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_log.csv', append=False)])

    live_metrics, y_true, y_pred, y_prob = full_test_metrics(model, te)
    print(f"\nLive (in-memory) test metrics, auc-selected: {live_metrics}")
    np.savez(f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_preds.npz',
             y_true=y_true, y_pred=y_pred, y_prob=y_prob,
             source=test_df['source'].values, group_id=test_df['group_id'].values)

    reloaded_auc_model = load_model(auc_path)
    reloaded_auc_metrics, _, _, _ = full_test_metrics(reloaded_auc_model, te)
    match = abs(live_metrics['macro_auc'] - reloaded_auc_metrics['macro_auc']) < 1e-3
    print(f"Reloaded auc-checkpoint macro_auc={reloaded_auc_metrics['macro_auc']:.4f} vs live={live_metrics['macro_auc']:.4f}, match={match}")
    assert match, "AUC-CHECKPOINT MISMATCH, invalid provenance, discard this result"
    del reloaded_auc_model

    best_val_acc_seen = max(hist.history['val_accuracy'])
    reloaded_acc_model = load_model(acc_path)
    reloaded_val_acc = reloaded_acc_model.evaluate(va, verbose=0)[1]
    match_acc = abs(best_val_acc_seen - reloaded_val_acc) < 1e-3
    print(f"Accuracy-checkpoint provenance: best val_accuracy seen during training={best_val_acc_seen:.4f} "
          f"vs reloaded val_accuracy={reloaded_val_acc:.4f}, match={match_acc}")
    assert match_acc, "ACCURACY-CHECKPOINT MISMATCH, invalid provenance, discard this result"
    reloaded_acc_metrics, _, _, _ = full_test_metrics(reloaded_acc_model, te)
    del reloaded_acc_model
    del model; import gc; gc.collect(); tf.keras.backend.clear_session()

    same_checkpoint = abs(reloaded_auc_metrics['macro_auc'] - reloaded_acc_metrics['macro_auc']) < 1e-6
    print(f"Monitors agreed on the same epoch: {same_checkpoint}")

    rows = [
        {'fold': CURRENT_FOLD, 'arch': arch_code, 'selected_by': 'val_auc', **reloaded_auc_metrics},
        {'fold': CURRENT_FOLD, 'arch': arch_code, 'selected_by': 'val_accuracy', **reloaded_acc_metrics},
    ]
    out_df = pd.DataFrame(rows)
    out_path = f'/kaggle/working/cv_f{CURRENT_FOLD}_{arch_code}_results.csv'
    out_df.to_csv(out_path, index=False)
    print(f"\nSaved {out_path}")
    print(out_df.round(4).to_string(index=False))
    return out_df

# ---- CUSTOM CNN ----
custom_results = train_and_evaluate('custom', build_custom_cnn, None, is_pretrained=False)

# ---- EFFICIENTNETB0 ----
eff_results = train_and_evaluate('eff', lambda: build_pretrained(EfficientNetB0), eff_pre, is_pretrained=True)

# ---- MOBILENETV2 ----
mob_results = train_and_evaluate('mob', lambda: build_pretrained(MobileNetV2), mob_pre, is_pretrained=True)

print(f"\n\n{'='*20} FOLD {CURRENT_FOLD}: CUSTOM + EFF + MOB DONE (3 of 4) {'='*20}")
print(pd.concat([custom_results, eff_results, mob_results], ignore_index=True).round(4).to_string(index=False))
print(f"\nDownload individually: cv_f{CURRENT_FOLD}_custom_results.csv, cv_f{CURRENT_FOLD}_eff_results.csv, cv_f{CURRENT_FOLD}_mob_results.csv")
print(f"Still needed for fold {CURRENT_FOLD}: res. Do not start fold 4 until all 4 exist.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 110.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, but you have tensorflow 2.19.0 which is incompatible.
# tf-keras 2.20.0 requires tensorflow<2.21,>=2.20, but you have tensorflow 2.19.0 which is incompatible.
# tensorflow-text 2.20.1 requires tensorflow<2.21,>=2.20.0, but you have tensorflow 2.19.0 which is incompatible.
# 2026-08-26 11:56:51.923789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1787745411.946849      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1787745411.954387      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1787745411.972774      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787745411.972790      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787745411.972793      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1787745411.972795      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seed 42 set, TF 2.19.0, tf.keras module: tf_keras.api._v2.keras
# Loaded 9,068 rows (expect 9,068)
#
# Fold 3: Train 6,163 (68.0%) | Val 1,089 (12.0%) | Test 1,816 (20.0%)
# ^^ RECORD THESE NUMBERS. The fold 3 ResNet50 session will assert reproduction against them.
#   aptos: train/val/test group-disjoint = True
#   eyepacs: train/val/test group-disjoint = True
#   messidor: train/val/test group-disjoint = True
# Fold 3 leakage check: PASS
# Fold 3 class_weight (fresh from this fold's train set): {np.str_('0'): np.float64(0.332), np.str_('1'): np.float64(2.051), np.str_('2'): np.float64(0.945), np.str_('3'): np.float64(4.911), np.str_('4'): np.float64(4.28)} | span 14.8x
# ^^ RECORD THIS SPAN too, same reproduction requirement.
# Found 6163 validated image filenames belonging to 5 classes.
# Found 1089 validated image filenames belonging to 5 classes.
# Found 1816 validated image filenames belonging to 5 classes.
# I0000 00:00:1787745445.998948      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1787745446.005129      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ===== Fold 3, custom: single phase, dual checkpoint =====
# Epoch 1/60
# E0000 00:00:1787745450.355018      22 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1787745453.099593      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787745456.115873      74 service.cc:152] XLA service 0x7894c83e2a70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1787745456.115906      74 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1787745456.115909      74 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1787745456.262140      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 193/193 [==============================] - 563s 3s/step - loss: 1.6452 - accuracy: 0.3321 - auc: 0.6304 - val_loss: 1.4503 - val_accuracy: 0.2011 - val_auc: 0.6987
# Epoch 2/60
# 193/193 [==============================] - 411s 2s/step - loss: 1.5221 - accuracy: 0.4579 - auc: 0.7365 - val_loss: 1.7734 - val_accuracy: 0.1423 - val_auc: 0.3686
# Epoch 3/60
# 193/193 [==============================] - 414s 2s/step - loss: 1.5187 - accuracy: 0.4748 - auc: 0.7425 - val_loss: 1.5877 - val_accuracy: 0.4233 - val_auc: 0.6522
# Epoch 4/60
# 193/193 [==============================] - 426s 2s/step - loss: 1.4951 - accuracy: 0.4983 - auc: 0.7634 - val_loss: 1.5240 - val_accuracy: 0.3691 - val_auc: 0.6465
# Epoch 5/60
# 193/193 [==============================] - 424s 2s/step - loss: 1.4871 - accuracy: 0.5124 - auc: 0.7663 - val_loss: 1.3499 - val_accuracy: 0.5170 - val_auc: 0.7708
# Epoch 6/60
# 193/193 [==============================] - 416s 2s/step - loss: 1.4718 - accuracy: 0.5358 - auc: 0.7874 - val_loss: 1.1457 - val_accuracy: 0.6253 - val_auc: 0.8341
# Epoch 7/60
# 193/193 [==============================] - 417s 2s/step - loss: 1.4669 - accuracy: 0.5272 - auc: 0.7842 - val_loss: 1.2515 - val_accuracy: 0.5813 - val_auc: 0.8383
# Epoch 8/60
# 193/193 [==============================] - 419s 2s/step - loss: 1.4695 - accuracy: 0.5207 - auc: 0.7794 - val_loss: 1.0599 - val_accuracy: 0.6566 - val_auc: 0.8579
# Epoch 9/60
# 193/193 [==============================] - 420s 2s/step - loss: 1.4635 - accuracy: 0.5306 - auc: 0.7866 - val_loss: 1.2489 - val_accuracy: 0.6520 - val_auc: 0.8427
# Epoch 10/60
# 193/193 [==============================] - 417s 2s/step - loss: 1.4581 - accuracy: 0.5455 - auc: 0.7932 - val_loss: 1.4593 - val_accuracy: 0.4454 - val_auc: 0.6933
# Epoch 11/60
# 193/193 [==============================] - 423s 2s/step - loss: 1.4660 - accuracy: 0.5546 - auc: 0.7929 - val_loss: 1.9398 - val_accuracy: 0.2948 - val_auc: 0.5264
# Epoch 12/60
# 193/193 [==============================] - 419s 2s/step - loss: 1.4556 - accuracy: 0.5624 - auc: 0.7952 - val_loss: 1.5470 - val_accuracy: 0.4242 - val_auc: 0.6569
# Epoch 13/60
# 193/193 [==============================] - 421s 2s/step - loss: 1.4483 - accuracy: 0.5638 - auc: 0.7968 - val_loss: 1.5473 - val_accuracy: 0.4031 - val_auc: 0.6423
# Epoch 14/60
# 193/193 [==============================] - 418s 2s/step - loss: 1.4436 - accuracy: 0.5724 - auc: 0.8055 - val_loss: 1.1571 - val_accuracy: 0.6290 - val_auc: 0.8405
# Epoch 15/60
# 193/193 [==============================] - 415s 2s/step - loss: 1.4405 - accuracy: 0.5650 - auc: 0.7990 - val_loss: 1.0507 - val_accuracy: 0.6134 - val_auc: 0.8536
#
# Live (in-memory) test metrics, auc-selected: {'qwk': np.float64(0.3919370569057834), 'macro_auc': np.float64(0.7095051984857043), 'accuracy': 0.6756607929515418, 'macro_f1': 0.33068955320057214, 'macro_sensitivity': 0.32366920357061835, 'macro_specificity': np.float64(0.8556621039761356), 'n_test': 1816}
# Reloaded auc-checkpoint macro_auc=0.7095 vs live=0.7095, match=True
# Accuracy-checkpoint provenance: best val_accuracy seen during training=0.6566 vs reloaded val_accuracy=0.6566, match=True
# Monitors agreed on the same epoch: True
#
# Saved /kaggle/working/cv_f3_custom_results.csv
#  fold   arch  selected_by    qwk  macro_auc  accuracy  macro_f1  macro_sensitivity  macro_specificity  n_test
#     3 custom      val_auc 0.3919     0.7095    0.6757    0.3307             0.3237             0.8557    1816
#     3 custom val_accuracy 0.3919     0.7095    0.6757    0.3307             0.3237             0.8557    1816
# Found 6163 validated image filenames belonging to 5 classes.
# Found 1089 validated image filenames belonging to 5 classes.
# Found 1816 validated image filenames belonging to 5 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
#
# ===== Fold 3, eff: PHASE 1 (head only, 10 epochs) =====
# Epoch 1/10
# E0000 00:00:1787752228.048456      22 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 193/193 [==============================] - 381s 2s/step - loss: 1.3806 - accuracy: 0.4741 - auc: 0.7818 - val_loss: 1.0615 - val_accuracy: 0.6015 - val_auc: 0.8636
# Epoch 2/10
# 193/193 [==============================] - 370s 2s/step - loss: 1.2223 - accuracy: 0.5502 - auc: 0.8430 - val_loss: 1.1651 - val_accuracy: 0.4545 - val_auc: 0.8139
# Epoch 3/10
# 193/193 [==============================] - 372s 2s/step - loss: 1.1699 - accuracy: 0.5690 - auc: 0.8571 - val_loss: 1.2695 - val_accuracy: 0.3903 - val_auc: 0.7743
# Epoch 4/10
# 193/193 [==============================] - 374s 2s/step - loss: 1.1437 - accuracy: 0.5823 - auc: 0.8631 - val_loss: 1.1099 - val_accuracy: 0.5188 - val_auc: 0.8380
# Epoch 5/10
# 193/193 [==============================] - 444s 2s/step - loss: 1.0957 - accuracy: 0.6004 - auc: 0.8719 - val_loss: 1.1050 - val_accuracy: 0.5491 - val_auc: 0.8393
# Epoch 6/10
# 193/193 [==============================] - 402s 2s/step - loss: 1.0839 - accuracy: 0.6073 - auc: 0.8772 - val_loss: 1.2683 - val_accuracy: 0.4316 - val_auc: 0.7774
# Epoch 7/10
# 193/193 [==============================] - 377s 2s/step - loss: 1.0576 - accuracy: 0.6218 - auc: 0.8817 - val_loss: 1.3146 - val_accuracy: 0.4334 - val_auc: 0.7648
# Epoch 8/10
# 193/193 [==============================] - 378s 2s/step - loss: 1.0307 - accuracy: 0.6180 - auc: 0.8833 - val_loss: 1.1479 - val_accuracy: 0.4876 - val_auc: 0.8205
# Epoch 9/10
# 193/193 [==============================] - 374s 2s/step - loss: 1.0472 - accuracy: 0.6159 - auc: 0.8822 - val_loss: 1.0767 - val_accuracy: 0.5344 - val_auc: 0.8458
# Epoch 10/10
# 193/193 [==============================] - 375s 2s/step - loss: 1.0275 - accuracy: 0.6278 - auc: 0.8859 - val_loss: 1.2380 - val_accuracy: 0.4031 - val_auc: 0.7884
#
# ===== Fold 3, eff: PHASE 2 (full fine-tune, dual checkpoint) =====
# Epoch 1/60
# E0000 00:00:1787756086.616882      22 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 193/193 [==============================] - 462s 2s/step - loss: 1.7639 - accuracy: 0.3211 - auc: 0.6612 - val_loss: 1.0763 - val_accuracy: 0.5969 - val_auc: 0.8577
# Epoch 2/60
# 193/193 [==============================] - 420s 2s/step - loss: 1.5101 - accuracy: 0.4005 - auc: 0.7340 - val_loss: 1.0171 - val_accuracy: 0.6116 - val_auc: 0.8694
# Epoch 3/60
# 193/193 [==============================] - 422s 2s/step - loss: 1.3984 - accuracy: 0.4469 - auc: 0.7704 - val_loss: 0.9928 - val_accuracy: 0.6051 - val_auc: 0.8737
# Epoch 4/60
# 193/193 [==============================] - 423s 2s/step - loss: 1.3303 - accuracy: 0.4740 - auc: 0.7963 - val_loss: 0.9674 - val_accuracy: 0.6134 - val_auc: 0.8803
# Epoch 5/60
# 193/193 [==============================] - 421s 2s/step - loss: 1.2619 - accuracy: 0.4902 - auc: 0.8064 - val_loss: 0.9531 - val_accuracy: 0.6263 - val_auc: 0.8841
# Epoch 6/60
# 193/193 [==============================] - 425s 2s/step - loss: 1.1992 - accuracy: 0.5234 - auc: 0.8281 - val_loss: 0.9381 - val_accuracy: 0.6299 - val_auc: 0.8880
# Epoch 7/60
# 193/193 [==============================] - 422s 2s/step - loss: 1.1878 - accuracy: 0.5238 - auc: 0.8313 - val_loss: 0.9245 - val_accuracy: 0.6299 - val_auc: 0.8912
# Epoch 8/60
# 193/193 [==============================] - 412s 2s/step - loss: 1.1658 - accuracy: 0.5389 - auc: 0.8410 - val_loss: 0.9159 - val_accuracy: 0.6235 - val_auc: 0.8929
# Epoch 9/60
# 193/193 [==============================] - 414s 2s/step - loss: 1.1157 - accuracy: 0.5548 - auc: 0.8509 - val_loss: 0.8996 - val_accuracy: 0.6318 - val_auc: 0.8968
# Epoch 10/60
# 193/193 [==============================] - 413s 2s/step - loss: 1.1018 - accuracy: 0.5533 - auc: 0.8567 - val_loss: 0.8809 - val_accuracy: 0.6437 - val_auc: 0.9014
# Epoch 11/60
# 193/193 [==============================] - 413s 2s/step - loss: 1.0727 - accuracy: 0.5624 - auc: 0.8617 - val_loss: 0.8768 - val_accuracy: 0.6446 - val_auc: 0.9022
# Epoch 12/60
# 193/193 [==============================] - 414s 2s/step - loss: 1.0499 - accuracy: 0.5869 - auc: 0.8698 - val_loss: 0.8666 - val_accuracy: 0.6547 - val_auc: 0.9045
# Epoch 13/60
# 193/193 [==============================] - 413s 2s/step - loss: 1.0407 - accuracy: 0.5828 - auc: 0.8728 - val_loss: 0.8559 - val_accuracy: 0.6584 - val_auc: 0.9066
# Epoch 14/60
# 193/193 [==============================] - 409s 2s/step - loss: 1.0080 - accuracy: 0.6028 - auc: 0.8800 - val_loss: 0.8503 - val_accuracy: 0.6630 - val_auc: 0.9081
# Epoch 15/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.9933 - accuracy: 0.6033 - auc: 0.8807 - val_loss: 0.8513 - val_accuracy: 0.6556 - val_auc: 0.9078
# Epoch 16/60
# 193/193 [==============================] - 416s 2s/step - loss: 0.9960 - accuracy: 0.6064 - auc: 0.8844 - val_loss: 0.8441 - val_accuracy: 0.6648 - val_auc: 0.9094
# Epoch 17/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.9632 - accuracy: 0.6114 - auc: 0.8869 - val_loss: 0.8339 - val_accuracy: 0.6657 - val_auc: 0.9119
# Epoch 18/60
# 193/193 [==============================] - 410s 2s/step - loss: 0.9671 - accuracy: 0.6237 - auc: 0.8902 - val_loss: 0.8396 - val_accuracy: 0.6667 - val_auc: 0.9105
# Epoch 19/60
# 193/193 [==============================] - 415s 2s/step - loss: 0.9413 - accuracy: 0.6262 - auc: 0.8930 - val_loss: 0.8394 - val_accuracy: 0.6657 - val_auc: 0.9104
# Epoch 20/60
# 193/193 [==============================] - 415s 2s/step - loss: 0.9250 - accuracy: 0.6339 - auc: 0.8963 - val_loss: 0.8238 - val_accuracy: 0.6731 - val_auc: 0.9140
# Epoch 21/60
# 193/193 [==============================] - 412s 2s/step - loss: 0.8951 - accuracy: 0.6414 - auc: 0.8976 - val_loss: 0.8201 - val_accuracy: 0.6786 - val_auc: 0.9146
# Epoch 22/60
# 193/193 [==============================] - 412s 2s/step - loss: 0.8905 - accuracy: 0.6377 - auc: 0.8998 - val_loss: 0.8170 - val_accuracy: 0.6823 - val_auc: 0.9155
# Epoch 23/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.8534 - accuracy: 0.6576 - auc: 0.9066 - val_loss: 0.8191 - val_accuracy: 0.6795 - val_auc: 0.9148
# Epoch 24/60
# 193/193 [==============================] - 412s 2s/step - loss: 0.8743 - accuracy: 0.6484 - auc: 0.9049 - val_loss: 0.8150 - val_accuracy: 0.6795 - val_auc: 0.9162
# Epoch 25/60
# 193/193 [==============================] - 410s 2s/step - loss: 0.8593 - accuracy: 0.6500 - auc: 0.9053 - val_loss: 0.8154 - val_accuracy: 0.6786 - val_auc: 0.9161
# Epoch 26/60
# 193/193 [==============================] - 413s 2s/step - loss: 0.8422 - accuracy: 0.6662 - auc: 0.9102 - val_loss: 0.8163 - val_accuracy: 0.6804 - val_auc: 0.9160
# Epoch 27/60
# 193/193 [==============================] - 418s 2s/step - loss: 0.8162 - accuracy: 0.6617 - auc: 0.9127 - val_loss: 0.8150 - val_accuracy: 0.6832 - val_auc: 0.9165
# Epoch 28/60
# 193/193 [==============================] - 416s 2s/step - loss: 0.8091 - accuracy: 0.6646 - auc: 0.9134 - val_loss: 0.8088 - val_accuracy: 0.6841 - val_auc: 0.9176
# Epoch 29/60
# 193/193 [==============================] - 417s 2s/step - loss: 0.7970 - accuracy: 0.6807 - auc: 0.9183 - val_loss: 0.8071 - val_accuracy: 0.6896 - val_auc: 0.9183
# Epoch 30/60
# 193/193 [==============================] - 411s 2s/step - loss: 0.7949 - accuracy: 0.6735 - auc: 0.9158 - val_loss: 0.8058 - val_accuracy: 0.6896 - val_auc: 0.9184
# Epoch 31/60
# 193/193 [==============================] - 410s 2s/step - loss: 0.7770 - accuracy: 0.6713 - auc: 0.9166 - val_loss: 0.8027 - val_accuracy: 0.6896 - val_auc: 0.9192
# Epoch 32/60
# 193/193 [==============================] - 419s 2s/step - loss: 0.7685 - accuracy: 0.6836 - auc: 0.9222 - val_loss: 0.8039 - val_accuracy: 0.6878 - val_auc: 0.9190
# Epoch 33/60
# 193/193 [==============================] - 414s 2s/step - loss: 0.7676 - accuracy: 0.6812 - auc: 0.9182 - val_loss: 0.8112 - val_accuracy: 0.6841 - val_auc: 0.9172
# Epoch 34/60
# 193/193 [==============================] - 415s 2s/step - loss: 0.7409 - accuracy: 0.6873 - auc: 0.9219 - val_loss: 0.7998 - val_accuracy: 0.6915 - val_auc: 0.9199
# Epoch 35/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.7339 - accuracy: 0.6852 - auc: 0.9224 - val_loss: 0.7973 - val_accuracy: 0.6896 - val_auc: 0.9202
# Epoch 36/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.7247 - accuracy: 0.7034 - auc: 0.9269 - val_loss: 0.8013 - val_accuracy: 0.6924 - val_auc: 0.9195
# Epoch 37/60
# 193/193 [==============================] - 413s 2s/step - loss: 0.7128 - accuracy: 0.6977 - auc: 0.9264 - val_loss: 0.7983 - val_accuracy: 0.6979 - val_auc: 0.9202
# Epoch 38/60
# 193/193 [==============================] - 437s 2s/step - loss: 0.7054 - accuracy: 0.7019 - auc: 0.9290 - val_loss: 0.7965 - val_accuracy: 0.6970 - val_auc: 0.9207
# Epoch 39/60
# 193/193 [==============================] - 426s 2s/step - loss: 0.6948 - accuracy: 0.7123 - auc: 0.9305 - val_loss: 0.8004 - val_accuracy: 0.6942 - val_auc: 0.9197
# Epoch 40/60
# 193/193 [==============================] - 411s 2s/step - loss: 0.6915 - accuracy: 0.7014 - auc: 0.9305 - val_loss: 0.7972 - val_accuracy: 0.6942 - val_auc: 0.9202
# Epoch 41/60
# 193/193 [==============================] - 407s 2s/step - loss: 0.6828 - accuracy: 0.7130 - auc: 0.9334 - val_loss: 0.7977 - val_accuracy: 0.6942 - val_auc: 0.9199
# Epoch 42/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.6718 - accuracy: 0.7073 - auc: 0.9307 - val_loss: 0.7968 - val_accuracy: 0.6961 - val_auc: 0.9211
# Epoch 43/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.6386 - accuracy: 0.7170 - auc: 0.9359 - val_loss: 0.8023 - val_accuracy: 0.6961 - val_auc: 0.9203
# Epoch 44/60
# 193/193 [==============================] - 414s 2s/step - loss: 0.6452 - accuracy: 0.7125 - auc: 0.9336 - val_loss: 0.7948 - val_accuracy: 0.7025 - val_auc: 0.9222
# Epoch 45/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.6174 - accuracy: 0.7316 - auc: 0.9420 - val_loss: 0.7955 - val_accuracy: 0.6970 - val_auc: 0.9213
# Epoch 46/60
# 193/193 [==============================] - 411s 2s/step - loss: 0.6228 - accuracy: 0.7259 - auc: 0.9400 - val_loss: 0.7986 - val_accuracy: 0.6961 - val_auc: 0.9218
# Epoch 47/60
# 193/193 [==============================] - 412s 2s/step - loss: 0.6343 - accuracy: 0.7221 - auc: 0.9373 - val_loss: 0.8036 - val_accuracy: 0.6905 - val_auc: 0.9205
# Epoch 48/60
# 193/193 [==============================] - 407s 2s/step - loss: 0.6192 - accuracy: 0.7289 - auc: 0.9395 - val_loss: 0.8069 - val_accuracy: 0.6878 - val_auc: 0.9193
# Epoch 49/60
# 193/193 [==============================] - 409s 2s/step - loss: 0.6085 - accuracy: 0.7229 - auc: 0.9393 - val_loss: 0.8029 - val_accuracy: 0.6860 - val_auc: 0.9209
# Epoch 50/60
# 193/193 [==============================] - 410s 2s/step - loss: 0.5907 - accuracy: 0.7360 - auc: 0.9427 - val_loss: 0.8031 - val_accuracy: 0.6924 - val_auc: 0.9214
# Epoch 51/60
# 193/193 [==============================] - 414s 2s/step - loss: 0.5801 - accuracy: 0.7357 - auc: 0.9452 - val_loss: 0.8144 - val_accuracy: 0.6887 - val_auc: 0.9200
#
# Live (in-memory) test metrics, auc-selected: {'qwk': np.float64(0.7210606235247541), 'macro_auc': np.float64(0.8731442668300973), 'accuracy': 0.6976872246696035, 'macro_f1': 0.5024173676852183, 'macro_sensitivity': 0.5323289422675059, 'macro_specificity': np.float64(0.9048176186429705), 'n_test': 1816}
# Reloaded auc-checkpoint macro_auc=0.8731 vs live=0.8731, match=True
# Accuracy-checkpoint provenance: best val_accuracy seen during training=0.7025 vs reloaded val_accuracy=0.7025, match=True
# Monitors agreed on the same epoch: True
#
# Saved /kaggle/working/cv_f3_eff_results.csv
#  fold arch  selected_by    qwk  macro_auc  accuracy  macro_f1  macro_sensitivity  macro_specificity  n_test
#     3  eff      val_auc 0.7211     0.8731    0.6977    0.5024             0.5323             0.9048    1816
#     3  eff val_accuracy 0.7211     0.8731    0.6977    0.5024             0.5323             0.9048    1816
# Found 6163 validated image filenames belonging to 5 classes.
# Found 1089 validated image filenames belonging to 5 classes.
# Found 1816 validated image filenames belonging to 5 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
#
# ===== Fold 3, mob: PHASE 1 (head only, 10 epochs) =====
# Epoch 1/10
# 193/193 [==============================] - 372s 2s/step - loss: 1.5003 - accuracy: 0.4332 - auc: 0.7458 - val_loss: 1.2748 - val_accuracy: 0.4298 - val_auc: 0.7843
# Epoch 2/10
# 193/193 [==============================] - 361s 2s/step - loss: 1.2727 - accuracy: 0.5142 - auc: 0.8219 - val_loss: 1.3428 - val_accuracy: 0.4454 - val_auc: 0.7519
# Epoch 3/10
# 193/193 [==============================] - 363s 2s/step - loss: 1.2235 - accuracy: 0.5338 - auc: 0.8295 - val_loss: 1.3118 - val_accuracy: 0.4004 - val_auc: 0.7544
# Epoch 4/10
# 193/193 [==============================] - 366s 2s/step - loss: 1.1924 - accuracy: 0.5483 - auc: 0.8434 - val_loss: 1.2498 - val_accuracy: 0.4399 - val_auc: 0.7846
# Epoch 5/10
# 193/193 [==============================] - 368s 2s/step - loss: 1.1616 - accuracy: 0.5609 - auc: 0.8502 - val_loss: 0.9415 - val_accuracy: 0.6253 - val_auc: 0.8886
# Epoch 6/10
# 193/193 [==============================] - 367s 2s/step - loss: 1.1278 - accuracy: 0.5724 - auc: 0.8568 - val_loss: 1.0539 - val_accuracy: 0.5528 - val_auc: 0.8577
# Epoch 7/10
# 193/193 [==============================] - 366s 2s/step - loss: 1.1167 - accuracy: 0.5830 - auc: 0.8623 - val_loss: 1.0460 - val_accuracy: 0.5491 - val_auc: 0.8553
# Epoch 8/10
# 193/193 [==============================] - 364s 2s/step - loss: 1.0960 - accuracy: 0.5866 - auc: 0.8671 - val_loss: 1.2929 - val_accuracy: 0.4013 - val_auc: 0.7638
# Epoch 9/10
# 193/193 [==============================] - 365s 2s/step - loss: 1.0913 - accuracy: 0.5869 - auc: 0.8654 - val_loss: 1.0717 - val_accuracy: 0.5225 - val_auc: 0.8466
# Epoch 10/10
# 193/193 [==============================] - 360s 2s/step - loss: 1.0792 - accuracy: 0.5702 - auc: 0.8642 - val_loss: 1.0889 - val_accuracy: 0.4986 - val_auc: 0.8388
#
# ===== Fold 3, mob: PHASE 2 (full fine-tune, dual checkpoint) =====
# Epoch 1/60
# 193/193 [==============================] - 418s 2s/step - loss: 1.6492 - accuracy: 0.4631 - auc: 0.7393 - val_loss: 0.9531 - val_accuracy: 0.6107 - val_auc: 0.8826
# Epoch 2/60
# 193/193 [==============================] - 384s 2s/step - loss: 1.3540 - accuracy: 0.5283 - auc: 0.8140 - val_loss: 0.9807 - val_accuracy: 0.6235 - val_auc: 0.8818
# Epoch 3/60
# 193/193 [==============================] - 387s 2s/step - loss: 1.2493 - accuracy: 0.5416 - auc: 0.8319 - val_loss: 1.0220 - val_accuracy: 0.6162 - val_auc: 0.8764
# Epoch 4/60
# 193/193 [==============================] - 385s 2s/step - loss: 1.1907 - accuracy: 0.5419 - auc: 0.8348 - val_loss: 1.0509 - val_accuracy: 0.6244 - val_auc: 0.8732
# Epoch 5/60
# 193/193 [==============================] - 381s 2s/step - loss: 1.1437 - accuracy: 0.5661 - auc: 0.8489 - val_loss: 1.0551 - val_accuracy: 0.5978 - val_auc: 0.8695
# Epoch 6/60
# 193/193 [==============================] - 379s 2s/step - loss: 1.1181 - accuracy: 0.5700 - auc: 0.8557 - val_loss: 1.0330 - val_accuracy: 0.6125 - val_auc: 0.8733
# Epoch 7/60
# 193/193 [==============================] - 381s 2s/step - loss: 1.0871 - accuracy: 0.5848 - auc: 0.8662 - val_loss: 1.0430 - val_accuracy: 0.5868 - val_auc: 0.8693
# Epoch 8/60
# 193/193 [==============================] - 377s 2s/step - loss: 1.0584 - accuracy: 0.5750 - auc: 0.8660 - val_loss: 1.0286 - val_accuracy: 0.5895 - val_auc: 0.8715
#
# Live (in-memory) test metrics, auc-selected: {'qwk': np.float64(0.6005892616221227), 'macro_auc': np.float64(0.8439628793206129), 'accuracy': 0.6161894273127754, 'macro_f1': 0.38209930389666047, 'macro_sensitivity': 0.445838238178547, 'macro_specificity': np.float64(0.8858667478579525), 'n_test': 1816}
# Reloaded auc-checkpoint macro_auc=0.8440 vs live=0.8440, match=True
# Accuracy-checkpoint provenance: best val_accuracy seen during training=0.6244 vs reloaded val_accuracy=0.6244, match=True
# Monitors agreed on the same epoch: False
#
# Saved /kaggle/working/cv_f3_mob_results.csv
#  fold arch  selected_by    qwk  macro_auc  accuracy  macro_f1  macro_sensitivity  macro_specificity  n_test
#     3  mob      val_auc 0.6006     0.8440    0.6162    0.3821             0.4458             0.8859    1816
#     3  mob val_accuracy 0.5078     0.8099    0.6261    0.3356             0.3749             0.8717    1816
#
#
# ==================== FOLD 3: CUSTOM + EFF + MOB DONE (3 of 4) ====================
#  fold   arch  selected_by    qwk  macro_auc  accuracy  macro_f1  macro_sensitivity  macro_specificity  n_test
#     3 custom      val_auc 0.3919     0.7095    0.6757    0.3307             0.3237             0.8557    1816
#     3 custom val_accuracy 0.3919     0.7095    0.6757    0.3307             0.3237             0.8557    1816
#     3    eff      val_auc 0.7211     0.8731    0.6977    0.5024             0.5323             0.9048    1816
#     3    eff val_accuracy 0.7211     0.8731    0.6977    0.5024             0.5323             0.9048    1816
#     3    mob      val_auc 0.6006     0.8440    0.6162    0.3821             0.4458             0.8859    1816
#     3    mob val_accuracy 0.5078     0.8099    0.6261    0.3356             0.3749             0.8717    1816
#
# Download individually: cv_f3_custom_results.csv, cv_f3_eff_results.csv, cv_f3_mob_results.csv
# Still needed for fold 3: res. Do not start fold 4 until all 4 exist.
